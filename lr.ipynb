# %% [markdown]
# <a href="https://colab.research.google.com/github/88FaHaD/ML/blob/main/lr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#Generating some sample data
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 3 * X + np.random.randn(100, 1)

# Visualizing the data
plt.scatter(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Sample Data')
plt.show()

# %%
# Fitting linear regression model
model = LinearRegression()
model.fit(X, y)

# Getting the coefficients
slope = model.coef_[0][0]
intercept = model.intercept_[0]

print("Slope:", slope)
print("Intercept:", intercept)

# Plotting the regression line
plt.scatter(X, y)
plt.plot(X, slope*X + intercept, color='red')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.show()
# Out:
# Slope: 2.968467510701019
# Intercept: 0.22215107744722928

# %%
# Evaluating the model
y_pred = model.predict(X)
mse = mean_squared_error(y, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.9924386487246482

# %%
#  Plotting histogram of residuals
residuals = y - y_pred
plt.hist(residuals, bins=20)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

# %%
# Cell 6: Making predictions
X_new = np.array([[2.5], [3.0]])
predictions = model.predict(X_new)
print("Predictions for X_new:", predictions)
# Out:
# Predictions for X_new: [[7.64331985]
#  [9.12755361]]
